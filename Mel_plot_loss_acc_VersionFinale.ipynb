# %% [markdown]
# Plotting training

# %%
import csv

with open('lstm_history.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

print(data)
# Out:
# [['epoch', 'acc', 'loss', 'val_acc', 'val_loss'], ['0', '0.782608687877655', '0.4261554479598999', '0.8392857313156128', '0.34000352025032043'], ['1', '0.9221014380455017', '0.2447461634874344', '0.9732142686843872', '0.10134056955575943'], ['2', '0.9583333134651184', '0.1405380666255951', '0.9821428656578064', '0.07761172205209732'], ['3', '0.9764492511749268', '0.0931791439652443', '0.9821428656578064', '0.07878969609737396'], ['4', '0.9900362491607666', '0.07024839520454407', '1.0', '0.03462051600217819'], ['5', '0.9211956262588501', '0.19221964478492737', '0.9464285969734192', '0.11105585843324661'], ['6', '0.98097825050354', '0.08566451072692871', '1.0', '0.035809773951768875'], ['7', '0.9836956262588501', '0.07517917454242706', '0.9910714030265808', '0.04044994339346886'], ['8', '0.9864130616188049', '0.06883399188518524', '1.0', '0.038781534880399704'], ['9', '0.991847813129425', '0.05999603122472763', '0.9464285969734192', '0.1591823548078537'], ['10', '0.9827898740768433', '
# ...

# %%
import pandas as pd
sed = pd.read_csv('lstm_history.csv')

# %%
sed['val_acc'].plot(figsize=(9,6))
sed['acc'].plot()
plt.title('model accuracy')
plt.legend()
plt.show()

# %%
sed['val_loss'].plot(figsize=(9,6))
sed['loss'].plot()
plt.title('model loss')
plt.legend()
plt.show()

# %%
import pandas as pd
sed = pd.read_csv('conv2d_history.csv')
sed['val_accuracy'].plot(figsize=(9,6))
sed['accuracy'].plot()
plt.title('model accuracy')
plt.legend()
plt.show()

# %%
sed['val_loss'].plot(figsize=(9,6))
sed['loss'].plot()
plt.title('model loss')
plt.legend()
plt.show()
